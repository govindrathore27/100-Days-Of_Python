# %%
MENU = {
    "espresso": {
        "ingredients": {
            "water": 50,
            "coffee": 18,
        },
        "cost": 1.5,
    },
    "latte": {
        "ingredients": {
            "water": 200,
            "milk": 150,
            "coffee": 24,
        },
        "cost": 2.5,
    },
    "cappuccino": {
        "ingredients": {
            "water": 250,
            "milk": 100,
            "coffee": 24,
        },
        "cost": 3.0,
    }
}

profit = 0
resources = {
    "water": 300,
    "milk": 200,
    "coffee": 100,
}
logo ="""
                       .
                        `:.
                          `:.
                  .:'     ,::
                 .:'      ;:'
                 ::      ;:'
                  :    .:'
                   `.  :.
          _________________________
         : _ _ _ _ _ _ _ _ _ _ _ _ :
     ,---:".".".".".".".".".".".".":
    : ,'"`::.:.:.:.:.:.:.:.:.:.:.::'
    `.`.  `:-===-===-===-===-===-:'
      `.`-._:                   :
        `-.__`.               ,' met.
    ,--------`"`-------------'--------.
     `"--.__                   __.--"'
            `""-------------""'


"""


def is_resource_sufficient(demand):
    '''
    Function to check if the resources are sufficient enough to make coffee.
    '''
    f = 0
    for i in demand:
        if demand[i] > resources[i]:
            print(f"Sorry! There is not enough {i} in the machine to process your request.")
            f +=1
    if f!=0:
        return False
    else:
        return True
    
def process_coins():
    '''
    Function to process coins ,i.e., to convert the coin names to corresponding amount
    and return total. 
    '''
    total = 0
    total += int(input("how many quarters?: ")) * 0.25
    total += int(input("how many dimes?: ")) * 0.1
    total += int(input("how many nickles?: ")) * 0.05
    total += int(input("how many pennies?: ")) * 0.01
    return total
    
def transaction_successful(total,coffee_cost):
    '''
    Function to check whether the transaction was successfull or not.
    '''
    if total >= coffee_cost:
        change = round(total - coffee_cost, 2)   
        if change != 0:
            print(f"Here is ${change} in change.")
            global profit
            profit += coffee_cost
            return True
        else:
            profit += coffee_cost
            return True
    else:
        print("Sorry that's not enough money. Money refunded.")
        return False

def print_report(resources):
    '''
    Function to print water , milk , coffee left and money earned.
    '''
    global profit
    print(f"Water: {resources['water']} ml")
    print(f"Milk: {resources['milk']} ml")
    print(f"Coffee: {resources['coffee']} g")
    print(f"Money: ${profit}")

    
def make_coffee(drink_name,order_ingredients):
    '''
    Function to deduct the resources as used by completing the user demand.
    '''
    for item in order_ingredients:
        resources[item] -= order_ingredients[item]
    print(f"Here is your {drink_name} ☕. Enjoy!")
is_on = True


while is_on:
    print(logo)
    choice = input("​What would you like? (espresso/latte/cappuccino): ").lower()
    if choice == "off":
        is_on = False
    elif choice == 'report':
        print_report(resources)
    else:
        drink = MENU[choice]
        if is_resource_sufficient(drink["ingredients"]):
            payment = process_coins()
            if transaction_successful(payment, drink["cost"]):
                make_coffee(choice, drink["ingredients"])
# Out:
#                        .
#                         `:.
#                           `:.
#                   .:'     ,::
#                  .:'      ;:'
#                  ::      ;:'
#                   :    .:'
#                    `.  :.
#           _________________________
#          : _ _ _ _ _ _ _ _ _ _ _ _ :
#      ,---:".".".".".".".".".".".".":
#     : ,'"`::.:.:.:.:.:.:.:.:.:.:.::'
#     `.`.  `:-===-===-===-===-===-:'
#       `.`-._:                   :
#         `-.__`.               ,' met.
#     ,--------`"`-------------'--------.
#      `"--.__                   __.--"'
#             `""-------------""'
#
#
#
# ​What would you like? (espresso/latte/cappuccino): espresso
# how many quarters?: 23
# how many dimes?: 4
# how many nickles?: 2
# how many pennies?: 1
# Here is $4.76 in change.
# Here is your espresso ☕. Enjoy!
#
#                        .
#                         `:.
#                           `:.
#                   .:'     ,::
# ...
